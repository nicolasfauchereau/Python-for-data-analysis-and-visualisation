# %%
# %load_ext load_style
# %load_style talk.css
# Out:
# <style>
#
# .rendered_html {
#     font-family: "proxima-nova", helvetica;
#     font-size: 130%;
#     line-height: 1.5;
# }
#
# .rendered_html h1 {
#     margin: 0.25em 0em 0.5em;
#     color: #015C9C;
#     text-align: center;
#     line-height: 1.2;
#     page-break-before: always;
# }
#
# .rendered_html h2 {
#     margin: 1.1em 0em 0.5em;
#     color: #26465D;
#     line-height: 1.2;
# }
#
# .rendered_html h3 {
#     margin: 1.1em 0em 0.5em;
#     color: #002845;
#     line-height: 1.2;
# }
#
# .rendered_html li {
#     line-height: 1.5;
# }
#
# /*.prompt {
#     font-size: 120%;
# }*/
#
# .CodeMirror-lines {
#     font-size: 110%;
# }
#
# /*.output_area {
#     font-size: 120%;
# }*/
#
# /*#notebook {
#     background-image: url('files/images/witewall_3.png');
# }*/
#
# h1.bigtitle {
#     margin: 4cm 1cm 4cm 1cm;
#     font-size: 300%;
# }
#
# h3.point {
#     font-size: 200%;
#     text-align: center;
#     margin: 2em 0em 2em 0em;
#     #26465D
# }
#
# .logo {
#     margin: 20px 0 20px 0;
# }
#
# a.anchor-link {
#     display: none;
# }
#
# h1.title {
#     font-size: 250%;
# }
#
# </style>

# %% [markdown]
# # Interactive visualisations in the browser with Python

# %% [markdown]
# In the past few years, the python (scientific) ecosystem has seen intense development of solutions aimed at bringing interactive data visualisation in the browser, through a set of libraries which basically interface with powerful JavaScript visualisations libraries such as `D3.js`, `leaflet.js` etc.
#
# In this demo we will see:
#
# + [MPLd3](http://mpld3.github.io/)
# + [bokeh](http://bokeh.pydata.org/)
# + [folium](https://github.com/wrobstory/folium)

# %%
import warnings

# %%
warnings.filterwarnings('ignore', category=DeprecationWarning)

# %%
import os, sys
import pandas as pd
import numpy as np
from numpy import ma
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %% [markdown]
# <hr size=6>

# %% [markdown]
# ## MPLD3

# %% [markdown]
# [MPLd3](http://mpld3.github.io/) is developed by [Jake VanderPlas](http://www.astro.washington.edu/users/vanderplas/)
#
# MPLD3 provides a simple API for exporting [matplotlib](http://matplotlib.org) graphics to HTML code which can be used within the browser, within standard web pages, blogs, or tools such as the IPython notebook.

# %%
import mpld3
from mpld3 import plugins
mpld3.enable_notebook()

# %%
xdf = pd.DataFrame(np.random.normal(size=(100)), columns=['A'])

# %%
f, ax= plt.subplots(figsize=(8,4)); 
ax.plot(xdf.index, xdf['A'], lw=2, color='b');
ax.set_xlim(40,80)
ax.grid(color='0.8')

# %% [markdown]
# ### you can connect ```plugins``` to the figure

# %%
f, ax= plt.subplots(figsize=(8,4)); 
plt.plot(xdf.index, xdf['A'], lw=2, color='b');
ax.set_xlim(40,80)
ax.grid(color='0.8')
plugins.connect(f, plugins.MousePosition(fontsize=16))

# %%
mpld3.save_html(f, './mpld3_figure.html')

# %% [markdown]
# + [open in a new tab](./mpld3_figure.html)
#
# + [some more examples](http://mpld3.github.io/examples/index.html) from the mpld3 gallery
#
# <hr size = 6>

# %% [markdown]
# ## BOKEH

# %% [markdown]
# [bokeh](http://bokeh.pydata.org/) is a library developed by [continuum analytics](http://continuum.io)
#
# from their website:
#
# *Bokeh is a Python interactive visualization library that targets modern web browsers for presentation. Its goal is to provide elegant, concise construction of novel graphics in the style of D3.js, but also deliver this capability with high-performance interactivity over very large or streaming datasets. Bokeh can help anyone who would like to quickly and easily create interactive plots, dashboards, and data applications.*

# %% [markdown]
# To know more about bokeh:
#
# [http://bokeh.pydata.org/](http://bokeh.pydata.org/)

# %% [markdown]
# if you use the [anaconda python distribution](), all the bokeh examples are saved in
#
#     ${anaconda}/Examples/bokeh

# %% [markdown]
# prepare the data: simple sine

# %%
x = np.linspace(0, 10, 1000)
y = np.sin(x)

# %%
from bokeh.plotting import figure, output_file, output_notebook, show

# %%
output_notebook()
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="63153236-ed3a-4a2e-930a-d1925c30f5d8">Loading BokehJS ...</span>
#     </div>

# %%
# create a new plot with a title and axis labels
p = figure(title="simple line example", x_axis_label='x', y_axis_label='y')

# add a line renderer with legend and line thickness
p.line(x, y, legend="sin(x)", line_width=2)

# show the results
show(p)
# Out:
#     <div class="plotdiv" id="27596693-23b8-4038-87c1-3fd3b2afbb1f"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("27596693-23b8-4038-87c1-3fd3b2afbb1f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '27596693-23b8-4038-87c1-3fd3b2afbb1f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"89ca9fc2-8056-47d9-8da2-827127b97387":{"roots":{"references":[{"attributes":{"plot":{"id":"29fc5ee1-f004-400d-9341-565e41889d67","subtype":"Figure","type":"Plot"}},"id":"a803dd00-8304-46ae-a06a-769d38f627ec","type":"WheelZoomTool"},{"attributes":{"callback":null},"id":"3133c740-bb38-49bd-9be6-e50bd82ae55c","type":"DataRange1d"},{"attributes":{"plot":{"id":"5967b5b0-392d-4634-812c-fbc3b338e99f","subtype":"Figure","type":"Plot"}},"id":"f7689556-9768-4ede-9e38-5e8dc089178c","type":"PanTool"},{"attributes":{"data_source":{"id":"1e80c237-0900-46cd-9aa0-8ffa1ba6c1af","type":"ColumnDataSource"},"glyph":{"id":"d140d9b1-8d85-4d99-8868-144cdba1977f","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"1d597c5a-f099-4f8c-bda3-b94c6ce2995f","type":"Line"},"selection_glyph":null},"id":"43c97b83-d845-4792-9818-12064765e90c","type":"GlyphRenderer"},{"attributes":{"legends":[["sin(x)",[{"id":"43c97b83-d845-4792-9818-12064765e90c","type":"GlyphRenderer"}]]],"plot":{"id":"5967b5b0-392d-4634-812c-fbc3b338e99f","subtype":"Figure","type":"Plot"}},"id":"65dcd411-db83-4607-9d49-f2b19e78f234","type":"Legend"},{"attributes":{},"id":"4c18a39c-8b19-4d96-9dba-d9c765fff318","type":"BasicTicker"},{"attributes":{"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"4ef3665f-fea1-4a3f-a0c3-49248e3319d9","type":"Line"},{"attributes":{"callback":null},"id":"b7d186b3-c5c1-41e5-bf6c-3469e6b65990","type":"DataRange1d"},{"attributes":{"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"93b7fdd3-4a6b-4296-8447-02cf53e4f6f0","type":"Line"},{"attributes":{"plot":{"id":"5967b5b0-392d-4634-812c-fbc3b338e99f","subtype":"Figure","type":"Plot"}},"id":"255b624d-266b-4844-ac9a-ae36c38bd1fd","type":"HelpTool"},{"attributes":{"data_source":{"id":"545d425b-ce5e-47bc-92ff-418e31686aa9","type":"ColumnDataSource"},"glyph":{"id":"93b7fdd3-4a6b-4296-8447-02cf53e4f6f0","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"35bf5b27-24ff-4db9-bfb0-eb2d9d1ada87","type":"Line"},"selection_glyph":null},"id":"47ad6318-e5a4-4c06-b370-67ac92408073","type":"GlyphRenderer"},{"attributes":{},"id":"a8d0b5c5-85aa-436c-b37b-d88ca77516e5","type":"ToolEvents"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"35bf5b27-24ff-4db9-bfb0-eb2d9d1ada87","type":"Line"},{"attributes":{"overlay":{"id":"e1400dde-65af-4586-8258-191834ae95f5","type":"BoxAnnotation"},"plot":{"id":"5967b5b0-392d-4634-812c-fbc3b338e99f","subtype":"Figure","type":"Plot"}},"id":"42eae22f-6c85-4c0a-b7f7-29146f726dff","type":"BoxZoomTool"},{"attributes":{},"id":"47836eb8-79d5-4864-8952-88c3ceda5925","type":"BasicTicker"},{"attributes":{"axis_label":"y","formatter":{"id":"2fe1c060-d7fe-4412-93e0-f502cda9e98e","type":"BasicTickFormatter"},"plot":{"id":"5967b5b0-392d-4634-812c-fbc3b338e99f","subtype":"Figure","type":"Plot"},"ticker":{"id":"4c18a39c-8b19-4d96-9dba-d9c765fff318","type":"BasicTicker"}},"id":"859ed09d-fe70-42f9-a5ae-50afa85c7c8d","type":"LinearAxis"},{"attributes":{"plot":{"id":"1a442886-d6c4-4722-9006-d1c6c9de8053","subtype":"Figure","type":"Plot"}},"id":"3aa7ea2a-550c-44e1-bdf5-6b6ff5d17861","type":"PanTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"1d597c5a-f099-4f8c-bda3-b94c6ce2995f","type":"Line"},{"attributes":{"data_source":{"id":"367a62e3-a45f-4ac4-8f10-e1ede6adba58","type":"ColumnDataSource"},"glyph":{"id":"4ef3665f-fea1-4a3f-a0c3-49248e3319d9","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"c9623a5c-6598-4851-b142-49547af7095a","type":"Line"},"selection_glyph":null},"id":"4fc9e271-aafb-4c58-a59d-2fe1fc942dbb","type":"GlyphRenderer"},{"attributes":{"below":[{"id":"075f4afb-7a76-485b-b51b-b44f6c40184a","type":"LinearAxis"}],"left":[{"id":"a8c0fbb2-9b6e-4f00-8dd6-4a9e309a ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[20]</strong>&gt;</code></p>

# %%
# !open sin.html

# %% [markdown]
# Or you can output to an HTML file
#
# **specify mode = "cdn" so it loads the javascript from the bokeh Content Delivery Network instead of
# the local copy**

# %%
output_file("sin.html", title="sin(x)", mode="cdn")

# create a new plot with a title and axis labels
p = figure(title="simple line example", x_axis_label='x', y_axis_label='y')

# add a line renderer with legend and line thickness
p.line(x, y, legend="sin(x)", line_width=2)

# show the results
show(p)
# Out:
#     <div class="plotdiv" id="91e5d815-f2a7-474e-9a18-e613aeec78ce"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("91e5d815-f2a7-474e-9a18-e613aeec78ce");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '91e5d815-f2a7-474e-9a18-e613aeec78ce' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"8ec336df-5c63-4b16-b2ec-41cf675e2576":{"roots":{"references":[{"attributes":{"plot":{"id":"29fc5ee1-f004-400d-9341-565e41889d67","subtype":"Figure","type":"Plot"}},"id":"a803dd00-8304-46ae-a06a-769d38f627ec","type":"WheelZoomTool"},{"attributes":{"data_source":{"id":"1e80c237-0900-46cd-9aa0-8ffa1ba6c1af","type":"ColumnDataSource"},"glyph":{"id":"d140d9b1-8d85-4d99-8868-144cdba1977f","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"1d597c5a-f099-4f8c-bda3-b94c6ce2995f","type":"Line"},"selection_glyph":null},"id":"43c97b83-d845-4792-9818-12064765e90c","type":"GlyphRenderer"},{"attributes":{"legends":[["sin(x)",[{"id":"43c97b83-d845-4792-9818-12064765e90c","type":"GlyphRenderer"}]]],"plot":{"id":"5967b5b0-392d-4634-812c-fbc3b338e99f","subtype":"Figure","type":"Plot"}},"id":"65dcd411-db83-4607-9d49-f2b19e78f234","type":"Legend"},{"attributes":{"dimension":1,"plot":{"id":"29fc5ee1-f004-400d-9341-565e41889d67","subtype":"Figure","type":"Plot"},"ticker":{"id":"9d7e8c6a-9a51-4b5a-ab46-e7126855f09e","type":"BasicTicker"}},"id":"0fb61f47-9ad1-4a8f-98ce-b3c8a9fe1013","type":"Grid"},{"attributes":{"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"4ef3665f-fea1-4a3f-a0c3-49248e3319d9","type":"Line"},{"attributes":{"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"93b7fdd3-4a6b-4296-8447-02cf53e4f6f0","type":"Line"},{"attributes":{"plot":{"id":"99a5129f-4751-40f6-9f15-b3f85f8add7e","subtype":"Figure","type":"Plot"}},"id":"65d6f15e-57b4-41d8-a2bb-824baca7a9b2","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"5967b5b0-392d-4634-812c-fbc3b338e99f","subtype":"Figure","type":"Plot"}},"id":"255b624d-266b-4844-ac9a-ae36c38bd1fd","type":"HelpTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"e1400dde-65af-4586-8258-191834ae95f5","type":"BoxAnnotation"},{"attributes":{},"id":"09e08eb8-2967-486a-8d3f-9b37673b02a2","type":"BasicTicker"},{"attributes":{},"id":"a8d0b5c5-85aa-436c-b37b-d88ca77516e5","type":"ToolEvents"},{"attributes":{"data_source":{"id":"0689fc0c-9bc3-462a-9468-3d1e21b78c5a","type":"ColumnDataSource"},"glyph":{"id":"eda57526-a3e0-41e6-a9b2-601a344e6698","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"2a61584c-cd84-44e6-91de-9605c4fed88d","type":"Line"},"selection_glyph":null},"id":"2ea22ff0-88e4-404c-8e80-875852e22d33","type":"GlyphRenderer"},{"attributes":{},"id":"47836eb8-79d5-4864-8952-88c3ceda5925","type":"BasicTicker"},{"attributes":{"plot":{"id":"1a442886-d6c4-4722-9006-d1c6c9de8053","subtype":"Figure","type":"Plot"}},"id":"3aa7ea2a-550c-44e1-bdf5-6b6ff5d17861","type":"PanTool"},{"attributes":{},"id":"df3d30d6-1783-4cc5-bfd9-86f70615d8e3","type":"ToolEvents"},{"attributes":{"plot":{"id":"5967b5b0-392d-4634-812c-fbc3b338e99f","subtype":"Figure","type":"Plot"}},"id":"c82bc37b-af4d-4e52-81ae-c8c6da913108","type":"ResizeTool"},{"attributes":{"plot":{"id":"99a5129f-4751-40f6-9f15-b3f85f8add7e","subtype":"Figure","type":"Plot"}},"id":"fe1bca78-e2ef-4334-bb0f-dfdbf91c0d77","type":"PanTool"},{"attributes":{"plot":{"id":"5967b5b0-392d-4634-812c-fbc3b338e99f","subtype":"Figure","type":"Plot"}},"id":"97387677-befc-4f1e-bccb-72d45b5cb98c","type":"WheelZoomTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"c9623a5c-6598-4851-b142-49547af7095a","type":"Line"},{"attributes":{"plot":{"id":"99a5129f-4751-40f6-9f15-b3f85f8add7e","subtype":"Figure","type":"Plot"}},"id":"ebd58a5f-6b4f-4b8a-b9a2-a76a50ff2cdf","type":"ResetTool"},{"attributes":{"below":[{"id":"bb60cc11-2e22-4212-b682-44b6ab91e874","type":"LinearAxis"}], ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[22]</strong>&gt;</code></p>

# %% [markdown]
# You can control the toolbar: here I want pan, box_zoom, rest, but not save etc

# %%
x = np.array([0.1, 0.5, 1.0, 1.5, 2.0, 2.5, 3.0])
y0 = x**2
y1 = 10**x
y2 = 10**(x**2)

# output to static HTML file
output_file("log_lines.html")

# create a new plot
p = figure(
   tools="pan,box_zoom,reset",
   y_axis_type="log", y_range=[0.001, 10**11], title="log axis example",
   x_axis_label='sections', y_axis_label='particles'
)

# add some renderers
p.line(x, x, legend="y=x")
p.circle(x, x, legend="y=x", fill_color="white", size=8)
p.line(x, y0, legend="y=x^2", line_width=3)
p.line(x, y1, legend="y=10^x", line_color="red")
p.circle(x, y1, legend="y=10^x", fill_color="red", line_color="red", size=6)
p.line(x, y2, legend="y=10^x^2", line_color="orange", line_dash="4 4")

# show the results
show(p)
# Out:
#     <div class="plotdiv" id="c6f4ef24-e2ac-4498-a8e3-a2916282c69d"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c6f4ef24-e2ac-4498-a8e3-a2916282c69d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c6f4ef24-e2ac-4498-a8e3-a2916282c69d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"a69f72ca-84f2-4e7c-8d40-0982f5c73ff9":{"roots":{"references":[{"attributes":{"dimension":1,"plot":{"id":"4a1a0478-a70b-4508-b397-675f64f26d4c","subtype":"Figure","type":"Plot"},"ticker":{"id":"e31476d7-7632-42d0-8c1c-249df61e8003","type":"LogTicker"}},"id":"87915587-8efe-4987-9ac5-3515596c5dd6","type":"Grid"},{"attributes":{"line_color":{"value":"orange"},"line_dash":[4,4],"x":{"field":"x"},"y":{"field":"y"}},"id":"5b7cfbe8-d31e-4c0a-8a47-24b5026c9c1f","type":"Line"},{"attributes":{"plot":{"id":"29fc5ee1-f004-400d-9341-565e41889d67","subtype":"Figure","type":"Plot"}},"id":"a803dd00-8304-46ae-a06a-769d38f627ec","type":"WheelZoomTool"},{"attributes":{"ticker":null},"id":"b1143d76-421b-4631-993e-75905db85066","type":"LogTickFormatter"},{"attributes":{"data_source":{"id":"1e80c237-0900-46cd-9aa0-8ffa1ba6c1af","type":"ColumnDataSource"},"glyph":{"id":"d140d9b1-8d85-4d99-8868-144cdba1977f","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"1d597c5a-f099-4f8c-bda3-b94c6ce2995f","type":"Line"},"selection_glyph":null},"id":"43c97b83-d845-4792-9818-12064765e90c","type":"GlyphRenderer"},{"attributes":{"callback":null},"id":"d25e557b-adc2-4aea-a6fa-6be27bc06975","type":"DataRange1d"},{"attributes":{"legends":[["sin(x)",[{"id":"43c97b83-d845-4792-9818-12064765e90c","type":"GlyphRenderer"}]]],"plot":{"id":"5967b5b0-392d-4634-812c-fbc3b338e99f","subtype":"Figure","type":"Plot"}},"id":"65dcd411-db83-4607-9d49-f2b19e78f234","type":"Legend"},{"attributes":{"dimension":1,"plot":{"id":"29fc5ee1-f004-400d-9341-565e41889d67","subtype":"Figure","type":"Plot"},"ticker":{"id":"9d7e8c6a-9a51-4b5a-ab46-e7126855f09e","type":"BasicTicker"}},"id":"0fb61f47-9ad1-4a8f-98ce-b3c8a9fe1013","type":"Grid"},{"attributes":{"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"4ef3665f-fea1-4a3f-a0c3-49248e3319d9","type":"Line"},{"attributes":{"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"93b7fdd3-4a6b-4296-8447-02cf53e4f6f0","type":"Line"},{"attributes":{},"id":"b8fb4bb8-1b2a-450d-aca6-5a5b5b338d30","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"5967b5b0-392d-4634-812c-fbc3b338e99f","subtype":"Figure","type":"Plot"}},"id":"255b624d-266b-4844-ac9a-ae36c38bd1fd","type":"HelpTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"e1400dde-65af-4586-8258-191834ae95f5","type":"BoxAnnotation"},{"attributes":{},"id":"09e08eb8-2967-486a-8d3f-9b37673b02a2","type":"BasicTicker"},{"attributes":{},"id":"a8d0b5c5-85aa-436c-b37b-d88ca77516e5","type":"ToolEvents"},{"attributes":{"data_source":{"id":"0689fc0c-9bc3-462a-9468-3d1e21b78c5a","type":"ColumnDataSource"},"glyph":{"id":"eda57526-a3e0-41e6-a9b2-601a344e6698","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"2a61584c-cd84-44e6-91de-9605c4fed88d","type":"Line"},"selection_glyph":null},"id":"2ea22ff0-88e4-404c-8e80-875852e22d33","type":"GlyphRenderer"},{"attributes":{"fill_color":{"value":"white"},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":8},"x":{"field":"x"},"y":{"field":"y"}},"id":"ba88df8d-4e97-44ef-b478-0a236be1c892","type":"Circle"},{"attributes":{"plot":{"id":"1a442886-d6c4-4722-9006-d1c6c9de8053","subtype":"Figure","type":"Plot"}},"id":"3aa7ea2a-550c-44e1-bdf5-6b6ff5d17861","type":"PanTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_dash":[4,4],"x":{"field":"x"},"y":{"field":"y"}},"id":"85a2cc7a-ae42-4de7-8e39-3e88c6b7133f","type":"Line"},{"attributes":{"plot":{"id":"5967b5b0-392d-4634-812c-fbc3b338e99f","subtype":"Figure","type":"Plot"}},"id":"c82bc37b-af4d-4e52-81ae-c8c6da913108","type":"ResizeTool"},{"attributes":{"plot" ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[23]</strong>&gt;</code></p>

# %% [markdown]
# <hr size=6>

# %% [markdown]
# ## FOLIUM

# %% [markdown]
# [folium](https://github.com/wrobstory/folium)  has been also been developed by [Rob Story](http://wrobstory.github.io/) to provide an interface to the [leaflet.js](http://leafletjs.com/) JavaScript mapping library

# %% [markdown]
# an example of what it can do is available at:
#
# [https://rawgit.com/nicolasfauchereau/PLUVAR/master/www/index.html](https://rawgit.com/nicolasfauchereau/PLUVAR/master/www/index.html)
